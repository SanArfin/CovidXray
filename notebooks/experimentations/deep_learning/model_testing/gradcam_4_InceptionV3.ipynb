# %% [markdown]
# # Grad-CAM + Grid Display Code in Colab

# %% [markdown]
# ## imports

# %%
# === IMPORTS ===
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from pathlib import Path
from PIL import Image

# %% [markdown]
# ## definitions to set by user

# %%
# set "machine" according to where you want to run the script
machine = 'local' # 'colab' or 'local'

# modelname:
model_name = 'inceptionv3_10'


# size to which the X-ray images have to be converted to (according to the model which is used):
IMG_HEIGHT, IMG_WIDTH = 299, 299

# %% [markdown]
# ## load directories on colab

# %%
if machine == 'colab':
    #from google.colab import files
    #files.upload()

    # load google drive when working on colab
    from google.colab import drive
    #drive.mount('/content/drive')
    drive.mount("/content/drive", force_remount=True)

# %% [markdown]
# ## definitions of paths

# %%
if machine == 'local':
#    paths to load data:
    base_path = r"..\\data\\"
    base_path_zip = os.path.join(base_path, "raw")                       # path where zip-file is
    base_path_raw = base_path_zip                                        # path where raw data is unziped to  (on local machine same as path where zip is)
    base_path_processed = os.path.join(base_path, "processed", "DL")     # path where processed data is saved

    # paths to save models:
    model_path = r"..\\Models\\local\\DL"
   
elif machine == 'colab':
    # paths to load data:
    base_path_drive     = '/content/drive/MyDrive/data'         # base path on DRIVE
    base_path_colab     =  '/content/data'                      # base path on COLAB
    base_path_zip       = os.path.join(base_path_drive, 'raw')  # path where zip-file is (on drive)
    base_path_raw       = os.path.join(base_path_colab, 'raw')  # path where raw data is unziped to (on colab machine not on drive)
    base_path_processed = os.path.join(base_path_colab, 'processed')  # path where processed data is saved (on colab machine not on drive)


    # paths to save models:
    model_path = '/content/drive/MyDrive/models/DL'

# %% [markdown]
# ## load fine-tuned model

# %%
# === LOAD FINETUNED MODEL ===

model_file = os.path.join(model_path, model_name + ".keras")

assert tf.io.gfile.exists(model_file), f"Model not found at {model_file}"
base_model = tf.keras.models.load_model(model_file)
print("Base-Model loaded successfully.")

base_model.summary()
# Out:
# Base-Model loaded successfully.
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,493,098 (146.84 MB)
#  Trainable params: 13,902,596 (53.03 MB)
#  Non-trainable params: 10,687,904 (40.77 MB)
#  Optimizer params: 13,902,598 (53.03 MB)

# %% [markdown]
# ## Get infos about layers in the already trained and fine-tuned model

# %%
dummy = np.arange(299*299*3).reshape(299,299,3).astype(np.float32)
dummy = np.expand_dims(dummy, axis=0)  # Adds batch dimension
base_model(dummy)
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=array([[0., 1., 0., 0.]], dtype=float32)>

# %%
# Get the model's layers
for i, layer in enumerate(base_model.layers):
    print(f"Layer {i}: {layer.name} - {layer.__class__.__name__}")
# Out:
# Layer 0: input_layer_7 - InputLayer
# Layer 1: inception_v3 - Functional
# Layer 2: global_average_pooling2d_3 - GlobalAveragePooling2D
# Layer 3: dense_15 - Dense
# Layer 4: dropout_6 - Dropout
# Layer 5: dense_16 - Dense
# Layer 6: dropout_7 - Dropout
# Layer 7: dense_17 - Dense
# Layer 8: dense_18 - Dense
# Layer 9: dense_19 - Dense

# %%
# Access the underlying layers of InceptionV3 within your fine-tuned model
inception_model = base_model.get_layer("inception_v3")

# Print all layers inside InceptionV3
for i, layer in enumerate(inception_model.layers):
    print(f"Layer {i}: {layer.name} - {layer.__class__.__name__}")
# Out:
# Layer 0: input_layer_6 - InputLayer
# Layer 1: conv2d_282 - Conv2D
# Layer 2: batch_normalization_282 - BatchNormalization
# Layer 3: activation_282 - Activation
# Layer 4: conv2d_283 - Conv2D
# Layer 5: batch_normalization_283 - BatchNormalization
# Layer 6: activation_283 - Activation
# Layer 7: conv2d_284 - Conv2D
# Layer 8: batch_normalization_284 - BatchNormalization
# Layer 9: activation_284 - Activation
# Layer 10: max_pooling2d_12 - MaxPooling2D
# Layer 11: conv2d_285 - Conv2D
# Layer 12: batch_normalization_285 - BatchNormalization
# Layer 13: activation_285 - Activation
# Layer 14: conv2d_286 - Conv2D
# Layer 15: batch_normalization_286 - BatchNormalization
# Layer 16: activation_286 - Activation
# Layer 17: max_pooling2d_13 - MaxPooling2D
# Layer 18: conv2d_290 - Conv2D
# Layer 19: batch_normalization_290 - BatchNormalization
# Layer 20: activation_290 - Activation
# Layer 21: conv2d_288 - Conv2D
# Layer 22: conv2d_291 - Conv2D
# Layer 23: batch_normalization_288 - BatchNormalization
# Layer 24: batch_normalization_291 - BatchNormalization
# Layer 25: activation_288 - Activation
# Layer 26: activation_291 - Activation
# Layer 27: average_pooling2d_27 - AveragePooling2D
# Layer 28: conv2d_287 - Conv2D
# Layer 29: conv2d_289 - Conv2D
# Layer 30: conv2d_292 - Conv2D
# Layer 31: conv2d_293 - Conv2D
# Layer 32: batch_normalization_287 - BatchNormalization
# Layer 33: batch_normalization_289 - BatchNormalization
# Layer 34: batch_normalization_292 - BatchNormalization
# Layer 35: batch_normalization_293 - BatchNormalization
# Layer 36: activation_287 - Activation
# Layer 37: activation_289 - Activation
# Layer 38: activation_292 - Activation
# Layer 39: activation_293 - Activation
# Layer 40: mixed0 - Concatenate
# Layer 41: conv2d_297 - Conv2D
# Layer 42: batch_normalization_297 - BatchNormalization
# Layer 43: activation_297 - Activation
# Layer 44: conv2d_295 - Conv2D
# Layer 45: conv2d_298 - Conv2D
# Layer 46: batch_normalization_295 - BatchNormalization
# Layer 47: batch_normalization_298 - BatchNormalization
# Layer 48: activation_295 - Activation
# Layer 49: activation_298 - Activation
# Layer 50: average_pooling2d_28 - AveragePooling2D
# Layer 51: conv2d_294 - Conv2D
# Layer 52: conv2d_296 - Conv2D
# Layer 53: conv2d_299 - Conv2D
# Layer 54: conv2d_300 - Conv2D
# Layer 55: batch_normalization_294 - BatchNormalization
# Layer 56: batch_normalization_296 - BatchNormalization
# Layer 57: batch_normalization_299 - BatchNormalization
# Layer 58: batch_normalization_300 - BatchNormalization
# Layer 59: activation_294 - Activation
# Layer 60: activation_296 - Activation
# Layer 61: activation_299 - Activation
# Layer 62: activation_300 - Activation
# Layer 63: mixed1 - Concatenate
# Layer 64: conv2d_304 - Conv2D
# Layer 65: batch_normalization_304 - BatchNormalization
# Layer 66: activation_304 - Activation
# Layer 67: conv2d_302 - Conv2D
# Layer 68: conv2d_305 - Conv2D
# Layer 69: batch_normalization_302 - BatchNormalization
# Layer 70: batch_normalization_305 - BatchNormalization
# Layer 71: activation_302 - Activation
# Layer 72: activation_305 - Activation
# Layer 73: average_pooling2d_29 - AveragePooling2D
# Layer 74: conv2d_301 - Conv2D
# Layer 75: conv2d_303 - Conv2D
# Layer 76: conv2d_306 - Conv2D
# Layer 77: conv2d_307 - Conv2D
# Layer 78: batch_normalization_301 - BatchNormalization
# Layer 79: batch_normalization_303 - BatchNormalization
# Layer 80: batch_normalization_306 - BatchNormalization
# Layer 81: batch_normalization_307 - BatchNormalization
# Layer 82: activation_301 - Activation
# Layer 83: activation_303 - Activation
# Layer 84: activation_306 - Activation
# Layer 85: activation_307 - Activation
# Layer 86: mixed2 - Concatenate
# Layer 87: conv2d_309 - Conv2D
# Layer 88: batch_normalization_309 - BatchNormalization
# Layer 89: activation_309 - Activation
# Layer 90: conv2d_310 - Conv2D
# Layer 91: batch_normalization_310 - BatchNormalization
# Layer 92: activation_310 - Activation
# Layer 93: conv2d_308 - Conv2D
# Layer 94: conv2d_311 - Conv2D
# Layer 95: batch_normalization_308 - BatchNormalization
# Layer 96: batch_normalization_311 - BatchNormalization
# Layer 97: activation_308 - Activation
# Layer 98: activation_311 - Activation
# Layer 99: max_pooling2d_14 - MaxPooling2D
# Layer 100: mixed3 - Concatenate
# Layer 101: conv2d_316 - Conv2D
# Layer 102: batch_normalization_316 - BatchNormalization
# Layer 103: activation_316 - Activation
# Layer 104: conv2d_317 - Conv2D
# Layer 105: batch_normalization_317 - BatchNormalization
# Layer 106: activation_317 - Activation
# Layer 107: conv2d_313 - Conv2D
# Layer 108: conv2d_318 - Conv2D
# Layer 109: batch_normalization_313 - BatchNormalization
# Layer 110: batch_normalization_318 - BatchNormalization
# Layer 111: activation_313 - Activation
# Layer 112: activation_318 - Activation
# Layer 113: conv2d_314 - Conv2D
# Layer 114: conv2d_319 - Conv2D
# Layer 115: batch_normalization_314 - BatchNormalization
# Layer 116: batch_normalization_319 - BatchNormalization
# Layer 117: activation_314 - Activation
# Layer 118: activation_319 - Activation
# Layer 119: average_pooling2d_30 - AveragePooling2D
# Layer 120: conv2d_312 - Conv2D
# Layer 121: conv2d_315 - Conv2D
# Layer 122: conv2d_320 - Conv2D
# Layer 123: conv2d_321 - Conv2D
# Layer 124: batch_normalization_312 - BatchNormalization
# Layer 125: batch_normalization_315 - BatchNormalization
# Layer 126: batch_normalization_320 - BatchNormalization
# Layer 127: batch_normalization_321 - BatchNormalization
# Layer 128: activation_312 - Activation
# Layer 129: activation_315 - Activation
# Layer 130: activation_320 - Activation
# Layer 131: activation_321 - Activation
# Layer 132: mixed4 - Concatenate
# Layer 133: conv2d_326 - Conv2D
# Layer 134: batch_normalization_326 - BatchNormalization
# Layer 135: activation_326 - Activation
# Layer 136: conv2d_327 - Conv2D
# Layer 137: batch_normalization_327 - BatchNormalization
# Layer 138: activation_327 - Activation
# Layer 139: conv2d_323 - Conv2D
# Layer 140: conv2d_328 - Conv2D
# Layer 141: batch_normalization_323 - BatchNormalization
# Layer 142: batch_normalization_328 - BatchNormalization
# Layer 143: activation_323 - Activation
# Layer 144: activation_328 - Activation
# Layer 145: conv2d_324 - Conv2D
# Layer 146: conv2d_329 - Conv2D
# Layer 147: batch_normalization_324 - BatchNormalization
# Layer 148: batch_normalization_329 - BatchNormalization
# Layer 149: activation_324 - Activation
# Layer 150: activation_329 - Activation
# Layer 151: average_pooling2d_31 - AveragePooling2D
# Layer 152: conv2d_322 - Conv2D
# Layer 153: conv2d_325 - Conv2D
# Layer 154: conv2d_330 - Conv2D
# Layer 155: conv2d_331 - Conv2D
# Layer 156: batch_normalization_322 - BatchNormalization
# Layer 157: batch_normalization_325 - BatchNormalization
# Layer 158: batch_normalization_330 - BatchNormalization
# Layer 159: batch_normalization_331 - BatchNormalization
# Layer 160: activation_322 - Activation
# Layer 161: activation_325 - Activation
# Layer 162: activation_330 - Activation
# Layer 163: activation_331 - Activation
# Layer 164: mixed5 - Concatenate
# Layer 165: conv2d_336 - Conv2D
# Layer 166: batch_normalization_336 - BatchNormalization
# Layer 167: activation_336 - Activation
# Layer 168: conv2d_337 - Conv2D
# Layer 169: batch_normalization_337 - BatchNormalization
# Layer 170: activation_337 - Activation
# Layer 171: conv2d_333 - Conv2D
# Layer 172: conv2d_338 - Conv2D
# Layer 173: batch_normalization_333 - BatchNormalization
# Layer 174: batch_normalization_338 - BatchNormalization
# Layer 175: activation_333 - Activation
# Layer 176: activation_338 - Activation
# Layer 177: conv2d_334 - Conv2D
# Layer 178: conv2d_339 - Conv2D
# Layer 179: batch_normalization_334 - BatchNormalization
# Layer 180: batch_normalization_339 - BatchNormalization
# Layer 181: activation_334 - Activation
# Layer 182: activation_339 - Activation
# Layer 183: average_pooling2d_32 - AveragePooling2D
# Layer 184: conv2d_332 - Conv2D
# Layer 185: conv2d_335 - Conv2D
# Layer 186: conv2d_340 - Conv2D
# Layer 187: conv2d_341 - Conv2D
# Layer 188: batch_normalization_332 - BatchNormalization
# Layer 189: batch_normalization_335 - BatchNormalization
# Layer 190: batch_normalization_340 - BatchNormalization
# Layer 191: batch_normalization_341 - BatchNormalization
# Layer 192: activation_332 - Activation
# Layer 193: activation_335 - Activation
# Layer 194: activation_340 - Activation
# Layer 195: activation_341 - Activation
# Layer 196: mixed6 - Concatenate
# Layer 197: conv2d_346 - Conv2D
# Layer 198: batch_normalization_346 - BatchNormalization
# Layer 199: activation_346 - Activation
# Layer 200: conv2d_347 - Conv2D
# Layer 201: batch_normalization_347 - BatchNormalization
# Layer 202: activation_347 - Activation
# Layer 203: conv2d_343 - Conv2D
# Layer 204: conv2d_348 - Conv2D
# Layer 205: batch_normalization_343 - BatchNormalization
# Layer 206: batch_normalization_348 - BatchNormalization
# Layer 207: activation_343 - Activation
# Layer 208: activation_348 - Activation
# Layer 209: conv2d_344 - Conv2D
# Layer 210: conv2d_349 - Conv2D
# Layer 211: batch_normalization_344 - BatchNormalization
# Layer 212: batch_normalization_349 - BatchNormalization
# Layer 213: activation_344 - Activation
# Layer 214: activation_349 - Activation
# Layer 215: average_pooling2d_33 - AveragePooling2D
# Layer 216: conv2d_342 - Conv2D
# Layer 217: conv2d_345 - Conv2D
# Layer 218: conv2d_350 - Conv2D
# Layer 219: conv2d_351 - Conv2D
# Layer 220: batch_normalization_342 - BatchNormalization
# Layer 221: batch_normalization_345 - BatchNormalization
# Layer 222: batch_normalization_350 - BatchNormalization
# Layer 223: batch_normalization_351 - BatchNormalization
# Layer 224: activation_342 - Activation
# Layer 225: activation_345 - Activation
# Layer 226: activation_350 - Activation
# Layer 227: activation_351 - Activation
# Layer 228: mixed7 - Concatenate
# Layer 229: conv2d_354 - Conv2D
# Layer 230: batch_normalization_354 - BatchNormalization
# Layer 231: activation_354 - Activation
# Layer 232: conv2d_355 - Conv2D
# Layer 233: batch_normalization_355 - BatchNormalization
# Layer 234: activation_355 - Activation
# Layer 235: conv2d_352 - Conv2D
# Layer 236: conv2d_356 - Conv2D
# Layer 237: batch_normalization_352 - BatchNormalization
# Layer 238: batch_normalization_356 - BatchNormalization
# Layer 239: activation_352 - Activation
# Layer 240: activation_356 - Activation
# Layer 241: conv2d_353 - Conv2D
# Layer 242: conv2d_357 - Conv2D
# Layer 243: batch_normalization_353 - BatchNormalization
# Layer 244: batch_normalization_357 - BatchNormalization
# Layer 245: activation_353 - Activation
# Layer 246: activation_357 - Activation
# Layer 247: max_pooling2d_15 - MaxPooling2D
# Layer 248: mixed8 - Concatenate
# Layer 249: conv2d_362 - Conv2D
# Layer 250: batch_normalization_362 - BatchNormalization
# Layer 251: activation_362 - Activation
# Layer 252: conv2d_359 - Conv2D
# Layer 253: conv2d_363 - Conv2D
# Layer 254: batch_normalization_359 - BatchNormalization
# Layer 255: batch_normalization_363 - BatchNormalization
# Layer 256: activation_359 - Activation
# Layer 257: activation_363 - Activation
# Layer 258: conv2d_360 - Conv2D
# Layer 259: conv2d_361 - Conv2D
# Layer 260: conv2d_364 - Conv2D
# Layer 261: conv2d_365 - Conv2D
# Layer 262: average_pooling2d_34 - AveragePooling2D
# Layer 263: conv2d_358 - Conv2D
# Layer 264: batch_normalization_360 - BatchNormalization
# Layer 265: batch_normalization_361 - BatchNormalization
# Layer 266: batch_normalization_364 - BatchNormalization
# Layer 267: batch_normalization_365 - BatchNormalization
# Layer 268: conv2d_366 - Conv2D
# Layer 269: batch_normalization_358 - BatchNormalization
# Layer 270: activation_360 - Activation
# Layer 271: activation_361 - Activation
# Layer 272: activation_364 - Activation
# Layer 273: activation_365 - Activation
# Layer 274: batch_normalization_366 - BatchNormalization
# Layer 275: activation_358 - Activation
# Layer 276: mixed9_0 - Concatenate
# Layer 277: concatenate_6 - Concatenate
# Layer 278: activation_366 - Activation
# Layer 279: mixed9 - Concatenate
# Layer 280: conv2d_371 - Conv2D
# Layer 281: batch_normalization_371 - BatchNormalization
# Layer 282: activation_371 - Activation
# Layer 283: conv2d_368 - Conv2D
# Layer 284: conv2d_372 - Conv2D
# Layer 285: batch_normalization_368 - BatchNormalization
# Layer 286: batch_normalization_372 - BatchNormalization
# Layer 287: activation_368 - Activation
# Layer 288: activation_372 - Activation
# Layer 289: conv2d_369 - Conv2D
# Layer 290: conv2d_370 - Conv2D
# Layer 291: conv2d_373 - Conv2D
# Layer 292: conv2d_374 - Conv2D
# Layer 293: average_pooling2d_35 - AveragePooling2D
# Layer 294: conv2d_367 - Conv2D
# Layer 295: batch_normalization_369 - BatchNormalization
# Layer 296: batch_normalization_370 - BatchNormalization
# Layer 297: batch_normalization_373 - BatchNormalization
# Layer 298: batch_normalization_374 - BatchNormalization
# Layer 299: conv2d_375 - Conv2D
# Layer 300: batch_normalization_367 - BatchNormalization
# Layer 301: activation_369 - Activation
# Layer 302: activation_370 - Activation
# Layer 303: activation_373 - Activation
# Layer 304: activation_374 - Activation
# Layer 305: batch_normalization_375 - BatchNormalization
# Layer 306: activation_367 - Activation
# Layer 307: mixed9_1 - Concatenate
# Layer 308: concatenate_7 - Concatenate
# Layer 309: activation_375 - Activation
# Layer 310: mixed10 - Concatenate

# %%
# find the last convolutional layer:
from tensorflow.keras.layers import Conv2D

# Find the last convolutional layer
conv_layers = [layer for layer in inception_model.layers if isinstance(layer, Conv2D)]
last_conv_layer = conv_layers[-1] if conv_layers else None

# Print details of the last conv layer
if last_conv_layer:
    print(f"Last Convolutional Layer: {last_conv_layer.name} - {last_conv_layer.__class__.__name__}")
else:
    print("No convolutional layers found!")
# Out:
# Last Convolutional Layer: conv2d_375 - Conv2D

# %% [markdown]
# ## we create a model that maps the input image to the activations of the last conv layer as well as the output predictions

# %%
# def build_gradcam_model(base_model, last_conv_layer_name='conv2d_375'):
#     grad_model = tf.keras.models.Model(
#         inputs=base_model.input,
#         outputs=[
#             base_model.get_layer(last_conv_layer_name).output,  # Conv output
#             base_model.output                                   # Predictions
#         ]
#     )
#     return grad_model

def build_gradcam_model(base_model, last_conv_layer_name='conv2d_375'):
    inception_submodel = base_model.get_layer('inception_v3')  # Get the wrapped InceptionV3 model
    grad_model = tf.keras.models.Model(
        inputs=base_model.input,
        outputs=[
            inception_submodel.get_layer(last_conv_layer_name).output,  # Conv output
            base_model.output  # Predictions
        ]
    )
    return grad_model


# Wrap it for Grad-CAM
model = build_gradcam_model(base_model)

# %%
#model.summary()

# %% [markdown]
# ## unzip X-ray images

# %%
archive_zip = 'covid19-radiography-database.zip'
unzipped_folder = 'COVID-19_Radiography_Dataset'

if machine == 'local':

    # only unzip if target folder not already exists:
    if not os.path.exists(os.path.join(base_path_raw,unzipped_folder)):
        with zipfile.ZipFile(os.path.join(base_path_zip, archive_zip), 'r') as zip_ref:
            for file_name in zip_ref.namelist():
                zip_ref.extract(file_name, base_path_raw)  # Extract files into target folder
            print("zip-archive {} unziped to folder: {}." .format(archive_zip, os.path.join(base_path_raw,unzipped_folder)))
    else:
        print('Nothing to unzip, folder already exist.')

elif machine == 'colab':
    # create directory
    os.makedirs(base_path_raw, exist_ok=True)
    os.makedirs(base_path_processed, exist_ok=True)

    # only unzip if target folder not already exists:
    if not os.path.exists(os.path.join(base_path_raw,unzipped_folder)):
        with zipfile.ZipFile(os.path.join(base_path_zip, archive_zip), 'r') as zip_ref:
            for file_name in zip_ref.namelist():
                zip_ref.extract(file_name, base_path_raw)  # Extract files into target folder
            print("zip-archive {} unziped to folder: {}." .format(archive_zip, os.path.join(base_path_raw,unzipped_folder)))
    else:
        print('Nothing to unzip, folder already exist.')
# Out:
# Nothing to unzip, folder already exist.

# %% [markdown]
# ## load X-ray images

# %%
#image_dir = Path(os.path.join(base_path_processed, "test_data_with_masks/COVID/images"))
image_dir = Path(os.path.join(base_path_processed, "test_data/COVID/images"))
image_files = sorted([
    str(image_dir / f) for f in os.listdir(image_dir)
    if f.lower().endswith(".png")
])[:20]  # Load first 20 test images

# Directory to save Grad-CAM results
grad_cam_dir = os.path.join(model_path, "grad_cam", model_name)
# create directory if not already exists:
os.makedirs(grad_cam_dir, exist_ok=True)

save_dir = Path(grad_cam_dir)
save_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Utility Functions: Image Preprocessing + Grad-CAM

# %%
# === IMAGE PREPROCESSING FUNCTION ===
def preprocess_image(image_path):
    """
    Loads and preprocesses an image for InceptionV3 model input.
    Returns the preprocessed image and the original PIL image.
    """
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    original_img = img.copy()
    img_array = tf.keras.preprocessing.image.img_to_array(img)#Saves a copy of the original image (PIL format) for later use in visualizations.
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.inception_v3.preprocess_input(img_array)
    return img_array, original_img

# === GRAD-CAM HEATMAP GENERATOR ===
def make_gradcam_heatmap(image, model, class_index=None):
    """
    Generates a Grad-CAM heatmap for a given image and model.
    """
    print("image.shape", image.shape, image.dtype)
    if len(image.shape) == 3:
        image = tf.expand_dims(image, axis=0)##Ensures the image is a 4D tensor (batch of 1) and cast to float (needed for gradient computation).

    print("image.shape", image.shape, image.dtype, type(image))
    
    #image = tf.cast(image, tf.float32)
    #print("image.shape", image.shape, image.dtype)


    with tf.GradientTape() as tape:
        print(f"model.inputshape", model.input_shape, model.input_dtype)
        conv_output, predictions = model(image) 
        tape.watch(conv_output) #Uses GradientTape to compute gradients of the predicted class score with respect to the last convolutional layer (conv_output

        # Get index of most confident class if not specified
        if class_index is None:
            class_index = tf.argmax(predictions[0])
        loss = predictions[:, class_index]

    grads = tape.gradient(loss, conv_output)
    pooled_grads = tf.reduce_mean(grads, axis=(1, 2))

    conv_output = conv_output[0]
    pooled_grads = pooled_grads[0]

    heatmap = tf.reduce_sum(tf.multiply(conv_output, pooled_grads), axis=-1)#Multiplies each channel in the conv output by its importance weight and sums 
    heatmap = tf.maximum(heatmap, 0)                                        #this gives us the class-discriminative localization map.
    heatmap /= tf.reduce_max(heatmap) + 1e-8                                # Normalize
    return heatmap.numpy(), predictions()                                   #Applies ReLU to keep only positive signals, and normalizes it to the [0,1] range for visualization.
#retuns a 2D NumPy array (the heatmap) indicating regions that contributed most to the class decision.

# If we want to do this for other classes too (like Normal, Lung_Opacity, etc.), we can loop through them like:
#for cls in ['Normal', 'COVID', 'Lung_Opacity', 'Viral Pneumonia']:
#    image_dir = f"/content/data/processed/test_data_with_masks/{cls}/images"
#    image_files = [...]  # same logic

# %% [markdown]
# #Generate and Save Grad-CAM Superimposed Images

# %%
print(f"base_model.inputshape", base_model.input_shape, base_model.input_dtype)
# Out:
# base_model.inputshape (None, 299, 299, 3) float32

# %%
# === GRAD-CAM OVERLAY AND SAVE ===
def generate_and_save_gradcam_images(model, image_files, save_dir, max_images=20):
    """
    Generates Grad-CAM overlays and saves them to disk.
    """
    save_dir = Path(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    for i, img_path in enumerate(image_files[:max_images]):
        img_array, original_img = preprocess_image(img_path)

        # Generate Grad-CAM heatmap and predictions
        heatmap, preds = make_gradcam_heatmap(img_array, model)
        pred_class = tf.argmax(preds[0]).numpy()
        confidence = tf.reduce_max(preds[0]).numpy()

        # Resize heatmap to original image size
        heatmap = cv2.resize(heatmap, original_img.size)
        heatmap = np.uint8(255 * heatmap)
        heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
        heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)

        # Blend original image and heatmap
        original_array = np.array(original_img.convert("RGB"))
        superimposed_img = cv2.addWeighted(original_array, 0.6, heatmap_color, 0.4, 0)

        # Save output image
        out_filename = save_dir / f"gradcam_{i+1}_class{pred_class}_conf{confidence:.2f}.jpg"
        Image.fromarray(superimposed_img).save(out_filename)

    print(f" Saved {len(image_files[:max_images])} Grad-CAM images to: {save_dir}")

#Run it
generate_and_save_gradcam_images(model, image_files, "gradcam_outputs", max_images=20)
# Out:
# image.shape (1, 299, 299, 3) float32
# image.shape (1, 299, 299, 3) float32 <class 'numpy.ndarray'>
# model.inputshape (None, 299, 299, 3) float32
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 34
#      31     print(f" Saved {len(image_files[:max_images])} Grad-CAM images to: {save_dir}")
#      33 #Run it
# ---> 34 generate_and_save_gradcam_images(model, image_files, "gradcam_outputs", max_images=20)
#
# Cell In[38], line 13, in generate_and_save_gradcam_images(model, image_files, save_dir, max_images)
#      10 img_array, original_img = preprocess_image(img_path)
#      12 # Generate Grad-CAM heatmap and predictions
# ---> 13 heatmap, preds = make_gradcam_heatmap(img_array, model)
#      14 pred_class = tf.argmax(preds[0]).numpy()
#      15 confidence = tf.reduce_max(preds[0]).numpy()
#
# Cell In[37], line 31, in make_gradcam_heatmap(image, model, class_index)
#      29 with tf.GradientTape() as tape:
#      30     print(f"model.inputshape", model.input_shape, model.input_dtype)
# ---> 31     model(image)
#      32     tape.watch(conv_output) #Uses GradientTape to compute gradients of the predicted class score with respect to the last convolutional layer (conv_output
#      34     # Get index of most confident class if not specified
#
# File c:\Users\Yvonne\Documents\DataScientist_2025_local\project_code\.venv-xray\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\Yvonne\Documents\DataScientist_2025_local\project_code\.venv-xray\Lib\site-packages\keras\src\ops\function.py:179, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     177 output_tensors = []
#     178 for x in self.outputs:
# --> 179     output_tensors.append(tensor_dict[id(x)])
#     181 return tree.pack_sequence_as(self._outputs_struct, output_tensors)
#
# KeyError: 'Exception encountered when calling Functional.call().\n\n\x1b2499142630624\x1b\n\nArguments received by Functional.call():\n  • inputs=array([[[[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [-1.        , -1.        , -1.        ],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-0.73333335, -0.73333335, -0.73333335]],\n\n        [[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [-1.        , -1.        , -1.        ],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-0.73333335, -0.73333335, -0.73333335]],\n\n        [[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [-1.        , -1.        , -1.        ],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-0.73333335, -0.73333335, -0.73333335]],\n\n        ...,\n\n        [[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [ 0.96862745,  0.96862745,  0.96862745],\n         [ 0.654902  ,  0.654902  ,  0.654902  ],\n         [-0.5686275 , -0.5686275 , -0.5686275 ]],\n\n        [[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [ 1.        ,  1.        ,  1.        ],\n         [ 0.6627451 ,  0.6627451 ,  0.6627451 ],\n         [-0.5686275 , -0.5686275 , -0.5686275 ]],\n\n        [[-0.73333335, -0.73333335, -0.73333335],\n         [-0.9529412 , -0.9529412 , -0.9529412 ],\n         [-1.        , -1.        , -1.        ],\n         ...,\n         [ 1.        ,  1.        ,  1.        ],\n         [ 0.654902  ,  0.654902  ,  0.654902  ],\n         [-0.5686275 , -0.5686275 , -0.5686275 ]]]], dtype=float32)\n  • training=None\n  • mask=None'

# %% [markdown]
# ## load directories on colab

# %% [markdown]
# #Create a Grid of Saved Grad-CAM Images

# %%
def create_gradcam_grid(image_dir, output_image_path, image_size=(128, 128), cols=5):
    """
    Loads saved Grad-CAM images and arranges them in a grid.
    """
    image_dir = Path(image_dir)
    image_files = sorted([
        f for f in os.listdir(image_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])[:15]

    all_images = []
    for img_name in image_files:
        img_path = image_dir / img_name
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"Failed to load: {img_path}")
            continue
        img = cv2.resize(img, image_size)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        all_images.append(img)

    # Create blank canvas for grid
    num_images = len(all_images)
    rows = (num_images + cols - 1) // cols
    grid_image = np.zeros((rows * image_size[1], cols * image_size[0], 3), dtype=np.uint8)

    for idx, img in enumerate(all_images):
        row = idx // cols
        col = idx % cols
        y = row * image_size[1]
        x = col * image_size[0]
        grid_image[y:y + image_size[1], x:x + image_size[0], :] = img

    # Save and display
    cv2.imwrite(output_image_path, cv2.cvtColor(grid_image, cv2.COLOR_RGB2BGR))
    plt.imshow(grid_image)
    plt.axis('off')
    plt.title('Grad-CAM Results Grid')
    plt.show()

    print(f" Grid image saved to: {output_image_path}")

# Run it
create_gradcam_grid(
    image_dir=save_dir,
    output_image_path=model_name + "_gradcam_grid.jpg"
)
# Out:
# Grid image saved to: vgg16_gradcam_grid.jpg
